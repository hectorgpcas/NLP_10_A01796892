# %% [markdown]
# #**Maestría en Inteligencia Artificial Aplicada**
# ##**Curso: Procesamiento de Lenguaje Natural (NLP)**
# ###Tecnológico de Monterrey
# ###Prof Luis Eduardo Falcón Morales
#
# ## **Adtividad de la Semana 02**
# ###**Introducción al procesamiento de texto.**

# %% [markdown]
# En esta actividad deberás utilizar los datos del siguiente archivo que se encuentra en Canvas:
#
# MNA_NLP_semana_02_Actividad_datos.txt
#
# El archivo contiene comentarios en inglés sobre servicios de comida de la página de Yelp: https://www.yelp.com/ .
#
# Son mil comentarios y forman parte del conjunto de datos que se encuentra en el Machine Learning Repository de la UCI, llamado "Sentiment Labelled Sentences": https://archive.ics.uci.edu/ml/datasets/Sentiment+Labelled+Sentences#

# %% [markdown]
# #**Parte 1. Cargamos los datos.**

# %% [markdown]
# Cargar los datos del archivo indicado y obtener una lista de longitud de 1000 strings/comentarios.
#
# Por el momento solamente requerimos las bibliotecas de Numpy y re, para el manejo de los arreglos y de las expresiones regulares en Python.
#
# En particular, no necesitarás en esta actividad la biblioteca de Pandas.
#
# ###**NOTA: En esta actividad no debes importar nada más, con estas dos bibliotecas será *suficiente*.**

# %%
import numpy as np    # importamos Numpy para el manejo de los arreglos.
import re             # importamos re para el manejo de las expresiones regulares.

# %%
# Ejecuta las siguientes instrucciones para cargar la información del achivo dado:

with open('MNA_NLP_semana_02_Actividad_datos.txt',        # puedes actualizar la ruta a tu archivo, en dado caso.
          mode='r',     # abrimos el archivo en modo lectura.
          ) as f:
    docs = f.readlines()    # separamos cada comentario por líneas

f.close()  # ya que tenemos la información en la variable docs, cerramos el archivo

# %%
type(docs) == list   # Verifica que tu variable "docs" es una lista
# Out:
# True

# %%
len(docs)==1000  # verifica que la longitud de "docs" es de mil comentarios.
# Out:
# True

# %%
docs[:10]     # observa algunos de los primeros comentarios
# Out:
# ['Wow... Loved this place.\n',
#  'Crust is not good.\n',
#  'Not tasty and the texture was just nasty.\n',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.\n',
#  'The selection on the menu was great and so were the prices.\n',
#  'Now I am getting angry and I want my damn pho.\n',
#  "Honeslty it didn't taste THAT fresh.)\n",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.\n',
#  'The fries were great too.\n',
#  'A great touch.\n']

# %% [markdown]
# #**Parte 2: sección de preguntas (regex).**

# %% [markdown]
# ##**Instrucciones:**
#
# ###**A continuación deberás contestar cada una de las preguntas que te piden usando expresiones regulares (regex).**
#
# ###**Por el momento no hay restricción en cuanto al número de líneas de código que agregues, pero trata de incluir las mínimas posibles.**

# %% [markdown]
# *   **Pregunta 1.**
#
# Busca y elimina todos los saltos de línea '\n' que se encuentran al final de cada comentario.
#
# Una vez finalizado, imprime los primeros 10 comentarios del resultado obtenido.

# %%
comments = [re.sub(r'\n$', '', doc) for doc in docs]

# %%
print("Primeros 10 resultados:")
comments[0:10]
# Out:
# Primeros 10 resultados:
# ['Wow... Loved this place.',
#  'Crust is not good.',
#  'Not tasty and the texture was just nasty.',
#  'Stopped by during the late May bank holiday off Rick Steve recommendation and loved it.',
#  'The selection on the menu was great and so were the prices.',
#  'Now I am getting angry and I want my damn pho.',
#  "Honeslty it didn't taste THAT fresh.)",
#  'The potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer.',
#  'The fries were great too.',
#  'A great touch.']

# %% [markdown]
# *   **Pregunta 2.**
#
# Busca e imprime todas las palabras que terminan con dos o más signos de admiración seguidos, por ejemplo "!!!".
#
# Debes imprimir tanto la palabra como la totalidad de signos de admiración que le siguen.
#
# Indica cuántos resultados obtuviste.

# %%
text = " ".join(comments) #se unen los comentarios de la lista para tener un solo string (se utiliza en el resto del ejercicio)
matches = re.findall(r"\b[A-Za-z]+!{2,}", text)
print(matches)
# Out:
# ['Firehouse!!!!!', 'APPETIZERS!!!', 'amazing!!!', 'buffet!!!', 'good!!', 'it!!!!', 'DELICIOUS!!', 'amazing!!', 'shawarrrrrrma!!!!!!', 'yucky!!!', 'steak!!!!!', 'delicious!!!', 'far!!', 'biscuits!!!', 'dry!!', 'disappointing!!!', 'awesome!!', 'Up!!', 'FLY!!!!!!!!', 'here!!!', 'great!!!!!!!!!!!!!!', 'packed!!', 'otherwise!!', 'amazing!!!!!!!!!!!!!!!!!!!', 'style!!', 'disappointed!!']

# %%
print(f"Total de palabras con 2 o más signos de admiración: {len(matches)}")
# Out:
# Total de palabras con 2 o más signos de admiración: 26

# %% [markdown]
# *   **Pregunta 3.**
#
# Busca e imprime todas las palabras que están escritas totalmente en mayúsculas. Cada coincidencia debe ser una sola palabra.
#
# Indica cuántas palabras encontraste.

# %%
capital_words = re.findall(r"\b[A-Z]{2,}\b",  text)
print(capital_words)
# Out:
# ['THAT', 'APPETIZERS', 'WILL', 'NEVER', 'EVER', 'STEP', 'FORWARD', 'IN', 'IT', 'AGAIN', 'LOVED', 'AND', 'REAL', 'BITCHES', 'NYC', 'STALE', 'DELICIOUS', 'WORST', 'EXPERIENCE', 'EVER', 'ALL', 'BARGAIN', 'TV', 'NONE', 'FREEZING', 'AYCE', 'FLAVOR', 'NEVER', 'BBQ', 'UNREAL', 'OMG', 'BETTER', 'BLAND', 'RUDE', 'INCONSIDERATE', 'MANAGEMENT', 'WILL', 'NEVER', 'EVER', 'GO', 'BACK', 'AND', 'HAVE', 'TOLD', 'MANY', 'PEOPLE', 'WHAT', 'HAD', 'HAPPENED', 'TOTAL', 'WASTE', 'OF', 'TIME', 'FS', 'AZ', 'LOVED', 'CONCLUSION', 'BEST', 'GO', 'NOW', 'GC', 'AVOID', 'THIS', 'ESTABLISHMENT', 'AN', 'HOUR', 'NASTY', 'OMG', 'NO', 'BEST', 'THE', 'OWNERS', 'REALLY', 'REALLY', 'PERFECT', 'SCREAMS', 'LEGIT', 'MGM', 'BEST', 'FLY', 'FLY', 'FANTASTIC', 'GREAT', 'OK', 'WAY', 'MUST', 'HAVE', 'OK', 'OVERPRICED', 'BARE', 'HANDS', 'WEAK', 'SHOULD', 'RI', 'VERY', 'NOT']

# %%
print("Total palabras con mayúsculas:", len(capital_words))
# Out:
# Total palabras con mayúsculas: 96

# %% [markdown]
# *   **Pregunta 4.**
#
# Busca e imprime los comentarios en donde todos los caracteres alfabéticos (letras) están en mayúsculas.
#
# Cada coincidencia encontrada debe ser todo el comentario/enunciado.
#
# Indica cuántos resultados obtuviste.

# %%
uppercase_comments = []
for comment in comments:
    if not re.search(r'[a-z]', comment):
        uppercase_comments.append(comment)

print(uppercase_comments)
# Out:
# ['DELICIOUS!!', 'RUDE & INCONSIDERATE MANAGEMENT.', 'WILL NEVER EVER GO BACK AND HAVE TOLD MANY PEOPLE WHAT HAD HAPPENED.', 'TOTAL WASTE OF TIME.', 'AVOID THIS ESTABLISHMENT!']

# %%
print(f"Total de comentarios con todos los caracteres alfabéticos en mayúsculas: {len(uppercase_comments)}")
# Out:
# Total de comentarios con todos los caracteres alfabéticos en mayúsculas: 5

# %% [markdown]
# *   **Pregunta 5.**
#
# Busca e imprime todas las palabras que tengan una vocal acentuada, del tipo á, é, í, ó, ú.
#
# Indica cuántos resultados obtuviste.

# %%
accents = re.findall(r"\b\w*[áéíóúÁÉÍÓÚ]\w*\b", text)
print(accents)
# Out:
# ['fiancé', 'Café', 'puréed']

# %%
print(f"Total de palabras con acento: {len(accents)}")
# Out:
# Total de palabras con acento: 3

# %% [markdown]
# *   **Pregunta 6.**
#
# Busca e imprime todas las cantidades numéricas monetarias, enteras o con decimales, que inician con el símbolo $\$$.
#
# Indica cuántos resultados obtuviste.

# %%
money = re.findall(r"\$\d+(?:\.\d+)?", text)
print(money)
# Out:
# ['$20', '$4.00', '$17', '$3', '$35', '$7.85', '$12', '$11.99']

# %%
print(f"Total de resultados obtenidos: {len(money)}")
# Out:
# Total de resultados obtenidos: 8

# %% [markdown]
# *   **Pregunta 7.**
#
# Busca e imprime todas las palabras que sean variantes de la palabra "love", sin importar si incluyen mayúsculas o minúsculas, o la manera en que esté conjugada o alguna otra variación que se haga con dicha palabra.
#
# Indica cuántos resultados obtuviste.

# %%
love_words = re.findall(r"\blove\w*\b", text, re.IGNORECASE)
print(love_words)
# Out:
# ['Loved', 'loved', 'Loved', 'love', 'loves', 'LOVED', 'lovers', 'love', 'lovers', 'Love', 'loved', 'loved', 'love', 'love', 'love', 'loved', 'love', 'loved', 'Love', 'LOVED', 'love', 'lovely', 'love', 'lovely', 'love', 'lover', 'loved', 'love', 'love', 'love', 'love', 'love', 'love', 'love', 'love']

# %%
print(f"Total de palabras que sean variantes de la palabra love: {len(love_words)}")
# Out:
# Total de palabras que sean variantes de la palabra love: 35

# %% [markdown]
# *   **Pregunta 8.**
#
# Busca e imprime todas las palabras, variantes de "so" y "good", que tengan dos o más "o" en "so" y 3 o más "o" en good.
#
# Indica cuántas encontraste.

# %%
so_good_words = re.findall(r"\bso{2,}\b|\bgo{3,}d\b", text, re.IGNORECASE)
print(so_good_words)
# Out:
# ['Sooooo', 'soooo', 'soooooo', 'soooo']

# %%
print("Resultados encontrados:", len(so_good_words))
# Out:
# Resultados encontrados: 4

# %% [markdown]
# *   **Pregunta 9.**
#
# Busca e imprime todas las palabras que tengan una longitud mayor estrictamente a 10 caracteres alfabéticos.
#
# No se consideran los signos de puntuación o caracteres especiales en la longitud de estas cadenas, solo caracteres alfabéticos en mayúsculas o minúsculas.
#
# Indica la cantidad de palabras encontradas.

# %%
words = re.findall(r'[A-Za-z]+', text)

# Filtrar palabras con longitud estrictamente mayor a 10
long_words = [p for p in words if len(p) > 10]

# Eliminar duplicados (opcional, si quieres únicas)
unique_words = list(set(long_words))

print(unique_words)
# Out:
# ['establishment', 'exceptional', 'recommended', 'connoisseur', 'Furthermore', 'replenished', 'drastically', 'disapppointment', 'grandmother', 'unexperienced', 'recommending', 'compliments', 'unfortunately', 'Unfortunately', 'profiterole', 'Veggitarian', 'ventilation', 'reservation', 'cheeseburger', 'unsatisfying', 'combination', 'experienced', 'outrageously', 'professional', 'Outstanding', 'unbelievable', 'presentation', 'disgraceful', 'considering', 'accordingly', 'underwhelming', 'constructed', 'neighborhood', 'disappointing', 'ingredients', 'caterpillar', 'undercooked', 'accommodations', 'anticipated', 'acknowledged', 'Disappointed', 'highlighted', 'INCONSIDERATE', 'Wienerschnitzel', 'unprofessional', 'disappointed', 'informative', 'descriptions', 'Mediterranean', 'transcendant', 'unbelievably', 'ESTABLISHMENT', 'Interesting', 'imaginative', 'cheesecurds', 'disappointment', 'imagination', 'maintaining', 'deliciously', 'opportunity', 'extraordinary', 'disrespected', 'immediately', 
# ...

# %%
print("Total palabras con > 10 caractéres alfabéticos:", len(long_words))
print("Total palabras únicas con > 10 caractéres alfabéticos:", len(unique_words))
# Out:
# Total palabras con > 10 caractéres alfabéticos: 141
# Total palabras únicas con > 10 caractéres alfabéticos: 88

# %% [markdown]
# *   **Pregunta 10.**
#
# Busca e imprime todas las palabras que inician con una letra mayúscula y terminan con una minúscula, pero que además no sea la primera palabra del comentario/string.
#
# Indica la cantidad de resultados obtenidos.

# %%
words_cap_low = []

for comment in comments:
    matches = re.findall(r'\b[A-Z][a-z]+\b', comment)

    words = re.findall(r'[A-Za-z]+', comment)

    if words:
        first = words[0]
        matches = [m for m in matches if m != first]

    words_cap_low.extend(matches)

words_cap_low = list(set(words_cap_low))
print(words_cap_low)
# Out:
# ['Jamaican', 'Flower', 'Bad', 'Ha', 'Thai', 'Shop', 'Pita', 'Hut', 'Mango', 'Great', 'Bunch', 'The', 'Mushroom', 'Bloody', 'Vegas', 'Hard', 'Chicken', 'Tucson', 'Mirage', 'Gordon', 'Magic', 'When', 'Best', 'Joey', 'Heart', 'Buffet', 'Toast', 'Casino', 'Indian', 'Up', 'Strip', 'Egg', 'North', 'Perfect', 'Place', 'Bean', 'Big', 'Nice', 'Sunday', 'Firehouse', 'Attack', 'Very', 'Not', 'Soi', 'Veggitarian', 'Wife', 'To', 'Rice', 'Roll', 'Scottsdale', 'Maria', 'Ians', 'Mexican', 'San', 'Buldogis', 'Noca', 'Kabuki', 'Risotto', 'Filet', 'Khao', 'Pizza', 'Pros', 'Frenchman', 'Macarons', 'Bar', 'Company', 'Chipotle', 'Outstanding', 'Baba', 'Gringos', 'Sushi', 'Yeah', 'Caesar', 'Maine', 'Yelpers', 'Pineapple', 'Bussell', 'Chinese', 'Luke', 'Eve', 'Las', 'Sat', 'Italian', 'Seat', 'Ramsey', 'Mmmm', 'In', 'Gold', 'Area', 'Dog', 'Stars', 'Loved', 'Sour', 'Cartel', 'Christmas', 'Otto', 'Service', 'Bellagio', 'Rick', 'Disappointed', 'Albondigas', 'This', 'Wienerschnitzel', 'Mandalay', 'Steiners', 'Th
# ...

# %%
print("Total palabras:", len(words_cap_low))
# Out:
# Total palabras: 205

# %% [markdown]
# *   **Pregunta 11.**
#
# Busca e imprime la secuencia de dos o más palabras que están separadas por un guion, "-", sin que tengan espacios en blanco entre ellas.
#
# Por ejemplo "Go-Kart" sería válido, pero "Go  -Kart" o "Go  -  Kart" no lo serían.
#
# Indica la cantidad de resultados obtenidos.

# %%
matches = re.findall(r'\b[A-Za-z]+(?:-[A-Za-z]+)+\b', text)
print(matches)
# Out:
# ['flat-lined', 'hands-down', 'must-stop', 'sub-par', 'Service-check', 'in-house', 'been-stepped-in-and-tracked-everywhere', 'multi-grain', 'to-go', 'non-customer', 'High-quality', 'sit-down', 'over-whelm', 'low-key', 'non-fancy', 'golden-crispy', 'over-priced', 'over-hip', 'under-services']

# %%
print("Secuencias encontradas:", len(matches))
# Out:
# Secuencias encontradas: 19

# %% [markdown]
# *   **Pregunta 12.**
#
# Busca e imprime todas las palabras que terminan en "ing" o "ed".
#
# Indica la cantidad de palabras que encontraste de cada una.

# %%
ing_words = re.findall(r'\b\w+(?:ing)\b', text)
unique_ing_words = list(set(ing_words))

ed_words = re.findall(r'\b\w+(?:ed)\b', text)
unique_ed_words = list(set(ed_words))

print("Palabras terminadas en 'ing':", unique_ing_words)
print("Palabras terminadas en 'end':", unique_ed_words)
# Out:
# Palabras terminadas en 'ing': ['boring', 'satisfying', 'sitting', 'thing', 'everything', 'freaking', 'dealing', 'looking', 'staying', 'driving', 'reviewing', 'loving', 'revisiting', 'craving', 'saving', 'appealing', 'rating', 'running', 'feeling', 'outshining', 'raving', 'waiting', 'redeeming', 'buying', 'sporting', 'recommending', 'appalling', 'editing', 'seating', 'seasoning', 'saying', 'refreshing', 'unsatisfying', 'pricing', 'making', 'hankering', 'Pricing', 'Outstanding', 'fucking', 'starving', 'including', 'building', 'talking', 'considering', 'setting', 'underwhelming', 'flirting', 'returning', 'spring', 'Coming', 'satifying', 'disappointing', 'getting', 'during', 'dripping', 'cooking', 'wasting', 'exceeding', 'working', 'nothing', 'charming', 'annoying', 'playing', 'inviting', 'giving', 'having', 'Interesting', 'lighting', 'dipping', 'providing', 'Everything', 'ordering', 'rotating', 'thinking', 'maintaining', 'hoping', 'lacking', 'asking', 'doing', 'venturing', 'writing', 'b
# ...

# %%
print("Total de palabras terminadas en 'ing':", len(ing_words))
print("Total de palabras únicas terminadas en 'ing':", len(unique_ing_words))
print('')
print("Total de palabras terminadas en 'end':", len(ed_words))
print("Total de palabras únicas terminadas en 'end':", len(unique_ed_words))
# Out:
# Total de palabras terminadas en 'ing': 279
# Total de palabras únicas terminadas en 'ing': 124
#
# Total de palabras terminadas en 'end': 335
# Total de palabras únicas terminadas en 'end': 176

# %% [markdown]
# #**Parte 3. Proceso de limpieza.**

# %% [markdown]
# *   **Pregunta 13.**
#
# Ahora realiza un proceso de limpieza del corpus que incluya los siguientes procesos:
#
# *   Solo se deben considerar caracteres alfabéticos. Es decir, se eliminan todos los signos de puntuación y caracteres especiales.
# *   Todos los caracteres alfabéticos se transforman a minúsculas.
# *   Se deben eliminar todos los espacios en blanco adicionales que se puedan encontrar en cada comentario.
#
# Al finalizar dicho proceso de limpieza, imprime el resultado de los primeros 10 comentarios resultantes.

# %%
clean_comments = []

for comment in comments:
    # 1. Solo letras y espacios
    text = re.sub(r'[^A-Za-z\s]', '', comment)

    # 2. Minúsculas
    text = text.lower()

    # 3. Quitar espacios extra
    text = re.sub(r'\s+', ' ', text).strip()

    clean_comments.append(text)

# %%
clean_comments[0:10]
# Out:
# ['wow loved this place',
#  'crust is not good',
#  'not tasty and the texture was just nasty',
#  'stopped by during the late may bank holiday off rick steve recommendation and loved it',
#  'the selection on the menu was great and so were the prices',
#  'now i am getting angry and i want my damn pho',
#  'honeslty it didnt taste that fresh',
#  'the potatoes were like rubber and you could tell they had been made up ahead of time being kept under a warmer',
#  'the fries were great too',
#  'a great touch']

# %% [markdown]
# *   **Pregunta 14.**
#
# Con el resultado de la limpieza obtenido en la pregunta anterior, realiza ahora un proceso de tokenización por palabras del corpus.
#
# Es decir, al final de este proceso de tokenización, debes tener como resultado una lista de listas, donde cada comentario estará tokenizado por palabras.
#
# Al terminar calcula el total de tokens obtenido en todo el corpus.

# %%
tokenized_comments = [comment.split() for comment in clean_comments]
print("Comentarios tokenizados:")
print(tokenized_comments)

total_tokens = sum(len(comment_tokens) for comment_tokens in tokenized_comments)
# Out:
# Comentarios tokenizados:
# ...

# %%
print(f"Total de tokens en el corpus: {total_tokens}")
# Out:
# Total de tokens en el corpus: 10777

# %% [markdown]
# *   **Pregunta 15.**
#
# Finalmente, en este ejercicio definiremos nuestro conjunto de palabras "stopwords", las cuales deberás eliminar de todo el corpus.
#
# Recuerda que ejemplos de stopwords son artículos, adverbios, conectivos, etcétera, que tienen frecuencias de aparición muy altas en cualquier documento, pero que no brindan mucho significado en cuanto al significado de un enunciado.
#
# Con base a la lista de stopwords que se te proporciona, realiza un proceso de limpieza eliminando todas estas palabras del corpus obtenido en el ejercicio anterior.
#
# Obtener cuántos tokens/palabras quedan finalmente en todo el corpus.
#
# Obtener cuántos de estos tokens/palabras son diferentes, es decir, cuántos tokens únicos tendrá lo que llamaremos más adelante nuestro vocabulario.

# %%
# Considera la siguiente lista como tu conjunto de stopwords:
mis_stopwords = ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', 'your', 'yours', 'he', 'him', 'his', 'himself', 'she', 'her', 'hers', 'herself', 'it', 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'should', 'now', 'll']

# %%
vocabulary = [
    [w for w in comment if w not in mis_stopwords]
    for comment in tokenized_comments
]

print(vocabulary)
# Out:
# [['wow', 'loved', 'place'], ['crust', 'not', 'good'], ['not', 'tasty', 'texture', 'nasty'], ['stopped', 'late', 'may', 'bank', 'holiday', 'off', 'rick', 'steve', 'recommendation', 'loved'], ['selection', 'menu', 'great', 'prices'], ['getting', 'angry', 'want', 'damn', 'pho'], ['honeslty', 'didnt', 'taste', 'fresh'], ['potatoes', 'like', 'rubber', 'could', 'tell', 'made', 'ahead', 'time', 'kept', 'warmer'], ['fries', 'great'], ['great', 'touch'], ['service', 'prompt'], ['would', 'not', 'go', 'back'], ['cashier', 'no', 'care', 'ever', 'say', 'still', 'ended', 'wayyy', 'overpriced'], ['tried', 'cape', 'cod', 'ravoli', 'chickenwith', 'cranberrymmmm'], ['disgusted', 'pretty', 'sure', 'human', 'hair'], ['shocked', 'no', 'signs', 'indicate', 'cash'], ['highly', 'recommended'], ['waitress', 'little', 'slow', 'service'], ['place', 'not', 'worth', 'time', 'let', 'alone', 'vegas'], ['not', 'like'], ['burrittos', 'blah'], ['food', 'amazing'], ['service', 'also', 'cute'], ['could', 'care', 'less'
# ...

# %%
total_vocabulary = sum(len(token) for token in vocabulary)
print("Total de vocabulario:", total_vocabulary)
# Out:
# Total de vocabulario: 5776

# %%
all_tokens = [w for comment in vocabulary for w in comment]
unique_tokens = set(all_tokens)
print("Total de tokens únicos:", len(unique_tokens))
# Out:
# Total de tokens únicos: 1941

# %% [markdown]
# *   **Comentarios**
#
# Incluye finalmente tus comentarios de la actividad.

# %% [markdown]
# Este tipo de análisis tienen una importante aplicación en negocios, pues permitió conocer el trasfondo y la programación de un sistema de análisis de texto con lenguaje natural (NLP) para identificar percepciones y sentimientos automatizado. Con dicho análisis, es posible obtener un panorama general de un conjunto de opiniones/reseñas sin necesidad de leer uno por uno los comentarios, ya que Python por medio de Regex lo puede hacer en cuestión de segundos. Todas estas instrucciones se pueden identar dentro de un pipeline que genere el análisis y limpieza de texto, de manera que se puedean generar herramientas de análisis de texto con machine learning que entreguen en cualquier momento un reporte listo para presentarse en una visualización clara que permita identificar reacciones positivas y negativas y con ello tomar decisiones de negocio y estrategias basadas en datos.

# %% [markdown]
# ##**Fin de la Actividad de la semana 2.**
